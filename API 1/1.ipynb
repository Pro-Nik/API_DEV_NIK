# %% [markdown]
# # This is the command to create a virtual environment

# %%
python -m venv myenv

# %% [markdown]
# # For activate the VE

# %%
nitish\Scripts\activate

# %% [markdown]
# # This is the command to install the fastapi configuration

# %% [markdown]
# pip install fastapi

# %% [markdown]
# pip install uvicorn

# %% [markdown]
# # Command to install all requirements

# %%
pip install -r requirements.txt

# %%
unicorn main:app --reload
